# %% [markdown]
# # Filtrar datos

# %%
# Importar la bibliteca de Pandas y cargar el archivo csv con todos los registros mque son más de 7 millones
# No se esta usando: , nrows = 1000000 en las comillas para delimitar la carga
import pandas as pd
df = pd.read_csv("D:/0.- TODO JORGE LUIS/4.- TODO POWER BI 2019/Certificados Linkedin/9. Python/base_datos_2008.csv")

# %%
# ver los 5 primeros registros de la columna ArrDealay
df["ArrDelay"].head()
# Out:
# 0   -14.0
# 1     2.0
# 2    14.0
# 3    -6.0
# 4    34.0
# Name: ArrDelay, dtype: float64

# %%
# Cantidad de filas y columnas
df.shape
# Out:
# (7009728, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Year               int64
#  1   Month              int64
#  2   DayofMonth         int64
#  3   DayOfWeek          int64
#  4   DepTime            float64
#  5   CRSDepTime         int64
#  6   ArrTime            float64
#  7   CRSArrTime         int64
#  8   UniqueCarrier      object
#  9   FlightNum          int64
#  10  TailNum            object
#  11  ActualElapsedTime  float64
#  12  CRSElapsedTime     float64
#  13  AirTime            float64
#  14  ArrDelay           float64
#  15  DepDelay           float64
#  16  Origin             object
#  17  Dest               object
#  18  Distance           int64
#  19  TaxiIn             float64
#  20  TaxiOut            float64
#  21  Cancelled          int64
#  22  CancellationCode   object
#  23  Diverted           int64
# ...

# %%
#ver los nombres de las columnas
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
origin_df = df["Origin"]

# %%
origin_df
# Out:
# 0          IAD
# 1          IAD
# 2          IND
# 3          IND
# 4          IND
#           ...
# 7009723    ATL
# 7009724    ATL
# 7009725    PBI
# 7009726    IAD
# 7009727    SAT
# Name: Origin, Length: 7009728, dtype: object

# %%
origin_df.head(10)
# Out:
# 0    IAD
# 1    IAD
# 2    IND
# 3    IND
# 4    IND
# 5    IND
# 6    IND
# 7    IND
# 8    IND
# 9    IND
# Name: Origin, dtype: object

# %%
origin_df[1000:1100]
# Out:
# 1000    OAK
# 1001    OAK
# 1002    OAK
# 1003    OAK
# 1004    OAK
#        ...
# 1095    OAK
# 1096    OAK
# 1097    OAK
# 1098    OAK
# 1099    OAK
# Name: Origin, Length: 100, dtype: object

# %%
# Columnas que no se ven
df[["TailNum", "ActualElapsedTime", 
    "CRSElapsedTime", "AirTime", "ArrDelay", 
    "DepDelay", "Origin", "Dest", "Distance"]].head(10)
# Out:
#   TailNum  ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  \
# 0  N712SW              128.0           150.0    116.0     -14.0       8.0
# 1  N772SW              128.0           145.0    113.0       2.0      19.0
# 2  N428WN               96.0            90.0     76.0      14.0       8.0
# 3  N612SW               88.0            90.0     78.0      -6.0      -4.0
# 4  N464WN               90.0            90.0     77.0      34.0      34.0
# 5  N726SW              101.0           115.0     87.0      11.0      25.0
# 6  N763SW              240.0           250.0    230.0      57.0      67.0
# 7  N428WN              233.0           250.0    219.0     -18.0      -1.0
# 8  N689SW               95.0            95.0     70.0       2.0       2.0
# 9  N648SW               79.0            95.0     70.0     -16.0       0.0
#
#   Origin Dest  Distance
# 0    IAD  TPA       810
# 1    IAD  TPA       810
# 2    IND  BWI       515
# 3    IND  BWI       515
# 4    IND  BWI       515
# ...

# %%
# ver las primeras 10 filas
df[0:10]
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %%
# Ver las filas 900000 a 900060
df[900000:900060]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 900000  2008      2          22          5   2139.0        2130   2354.0
# 900001  2008      2          22          5   2031.0        1950     42.0
# 900002  2008      2          22          5   1718.0        1718   1838.0
# 900003  2008      2          22          5    614.0         615    907.0
# 900004  2008      2          22          5   1003.0        1006   1619.0
# 900005  2008      2          22          5   1415.0        1250   1729.0
# 900006  2008      2          22          5   1809.0        1605   1925.0
# 900007  2008      2          22          5    741.0         745    952.0
# 900008  2008      2          22          5    732.0         730    906.0
# 900009  2008      2          22          5    739.0         730    902.0
# 900010  2008      2          22          5   1946.0        1848   2213.0
# 900011  2008      2          22          5   1210.0        1202   1436.0
# ...

# %%
# Vuelos retrazados menos de 1 hora
df[df["ArrDelay"] < 60].head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Vuelos retrazados más de 1 hora
df[df["ArrDelay"] > 60].head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 11  2008      1           3          4   1644.0        1510   1845.0
# 30  2008      1           3          4   2107.0        1945   2334.0
# 37  2008      1           3          4   1812.0        1650   1927.0
# 49  2008      1           3          4   2245.0        1730   2354.0
# 77  2008      1           3          4    958.0         900   1052.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 11        1725            WN       1333  ...    6.0      8.0          0
# 30        2230            WN        362  ...    6.0      7.0          0
# 37        1815            WN        422  ...    6.0     11.0          0
# 49        1850            WN        186  ...    3.0      7.0          0
# 77         950            WN       1574  ...    4.0     14.0          0
#
#     CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Vuelos retrazados exactamente 1 hora
df[df["ArrDelay"] == 60].head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 96    2008      1           3          4   2039.0        1930    155.0
# 423   2008      1           3          4   2117.0        2010   2355.0
# 610   2008      1           3          4   1942.0        1840   2205.0
# 1356  2008      1           3          4   1933.0        1835   1955.0
# 3574  2008      1           4          5   1600.0        1510   2355.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 96            55            WN       3940  ...    5.0     14.0          0
# 423         2255            WN       1485  ...    4.0     10.0          0
# 610         2105            WN       3332  ...    4.0      9.0          0
# 1356        1855            WN        921  ...    2.0     10.0          0
# 3574        2255            WN       3144  ...    5.0     13.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Vuelos que no se han retrazado 1 hora, significa de 59 para abajo y de 61 para arriba
df[df["ArrDelay"] != 60].head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Vuelos retrazados menor o igual a 1 hora
df[df["ArrDelay"] <= 60].head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Vuelos retrazados mayor o igual a 1 hora
df[df["ArrDelay"] >= 60].head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 11  2008      1           3          4   1644.0        1510   1845.0
# 30  2008      1           3          4   2107.0        1945   2334.0
# 37  2008      1           3          4   1812.0        1650   1927.0
# 49  2008      1           3          4   2245.0        1730   2354.0
# 77  2008      1           3          4    958.0         900   1052.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 11        1725            WN       1333  ...    6.0      8.0          0
# 30        2230            WN        362  ...    6.0      7.0          0
# 37        1815            WN        422  ...    6.0     11.0          0
# 49        1850            WN        186  ...    3.0      7.0          0
# 77         950            WN       1574  ...    4.0     14.0          0
#
#     CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Muestra el contenido de la columna Origin, las primeras 60 filas
df["Origin"].head(60)
# Out:
# 0     IAD
# 1     IAD
# 2     IND
# 3     IND
# 4     IND
# 5     IND
# 6     IND
# 7     IND
# 8     IND
# 9     IND
# 10    IND
# 11    IND
# 12    IND
# 13    IND
# 14    IND
# 15    IND
# 16    IND
# 17    IND
# 18    IND
# 19    ISP
# 20    ISP
# 21    ISP
# 22    ISP
# 23    ISP
# 24    ISP
# 25    ISP
# 26    ISP
# 27    ISP
# 28    ISP
# 29    ISP
# 30    ISP
# 31    ISP
# 32    ISP
# 33    ISP
# 34    ISP
# 35    ISP
# 36    ISP
# 37    ISP
# 38    ISP
# 39    ISP
# 40    ISP
# 41    ISP
# 42    ISP
# 43    ISP
# 44    ISP
# 45    ISP
# 46    ISP
# 47    JAN
# 48    JAN
# 49    JAN
# 50    JAN
# 51    JAN
# 52    JAN
# 53    JAN
# 54    JAN
# 55    JAN
# 56    JAX
# 57    JAX
# 58    JAX
# 59    JAX
# Name: Origin, dtype: object

# %%
# Muestra de la columna Origen los 5 primeros registros que sean de ATL Atlanta
df[df["Origin"] == "ATL"].head()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 103149  2008      1          21          1   1207.0        1210   1346.0
# 103572  2008      1          12          6   1458.0        1500   1622.0
# 104019  2008      1          20          7   1403.0        1330   1625.0
# 104124  2008      1          26          6   1629.0        1630   1832.0
# 104485  2008      1           4          5   1336.0        1340   1501.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 103149        1335            XE       2349  ...   11.0     13.0          0
# 103572        1620            XE       2145  ...    6.0     17.0          0
# 104019        1608            XE       1284  ...    6.0     32.0          0
# 104124        1902            XE       1241  ...    9.0     15.0          0
# 104485        1500            XE       2112  ...   12.0     12.0          0
#
# ...

# %%
# Muestra de la columna Origen los 5 primeros registros de ATL Y de la columna ArrDelay los vuelos retrazados más de 60 minutos
df[(df["Origin"] == "ATL") & (df["ArrDelay"] > 60)].head()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 109189  2008      1          31          4   1217.0        1210   1511.0
# 110375  2008      1          19          6   1241.0        1215   1735.0
# 121229  2008      1           3          4   1421.0        1200   1526.0
# 132768  2008      1           6          7   1315.0        1130   1410.0
# 133549  2008      1           7          1   2040.0        1800   2156.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 109189        1335            XE       2023  ...   21.0     60.0          0
# 110375        1437            XE       1284  ...   12.0    178.0          0
# 121229        1325            XE       2132  ...    9.0     13.0          0
# 132768        1240            YV       7267  ...    3.0      6.0          0
# 133549        1932            YV       2626  ...   12.0     28.0          0
#
# ...

# %%
# Muestra de la columna Origen los 5 primeros registros de ATL O de la columna ArrDelay los vuelos retrazados más de 60 minutos
df[(df["Origin"] == "ATL") | (df["ArrDelay"] > 60)].head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 11  2008      1           3          4   1644.0        1510   1845.0
# 30  2008      1           3          4   2107.0        1945   2334.0
# 37  2008      1           3          4   1812.0        1650   1927.0
# 49  2008      1           3          4   2245.0        1730   2354.0
# 77  2008      1           3          4    958.0         900   1052.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 11        1725            WN       1333  ...    6.0      8.0          0
# 30        2230            WN        362  ...    6.0      7.0          0
# 37        1815            WN        422  ...    6.0     11.0          0
# 49        1850            WN        186  ...    3.0      7.0          0
# 77         950            WN       1574  ...    4.0     14.0          0
#
#     CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Muestra de la columna Origen, los de Houston y Atlanta, los primeros 5 registros usando la función isin
df[df.Origin.isin(["HOU","ATL"])].head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 3269  2008      1           4          5   1910.0        1910   2025.0
# 3270  2008      1           4          5   1345.0        1345   1453.0
# 3271  2008      1           4          5    736.0         735    839.0
# 3272  2008      1           4          5   1603.0        1550   1647.0
# 3273  2008      1           4          5   2105.0        2105   2151.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 3269        2025            WN        823  ...    6.0     11.0          0
# 3270        1500            WN        901  ...    3.0     14.0          0
# 3271         850            WN        957  ...    3.0      9.0          0
# 3272        1635            WN        231  ...    5.0     10.0          0
# 3273        2150            WN        570  ...    7.0     11.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Nos permite saber todos aquellos registros donde no tenemos ningún valor en la columna ArrDelay
# con la función isna y pd de pandas
df[pd.isna(df["ArrDelay"])].head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178  2008      1           3          4      NaN         700      NaN
# 373  2008      1           3          4      NaN        1100      NaN
# 399  2008      1           3          4      NaN         905      NaN
# 401  2008      1           3          4      NaN        1620      NaN
# 415  2008      1           3          4      NaN        1930      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 178         830            WN        126  ...    NaN      NaN          1
# 373        1215            WN       1146  ...    NaN      NaN          1
# 399        1025            WN        469  ...    NaN      NaN          1
# 401        1740            WN        618  ...    NaN      NaN          1
# 415        2035            WN       2528  ...    NaN      NaN          1
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Nos permite ver la cantidad de filas que no tienen ningún valor de la base de datos completa de la columna ArrDelay
len(df[pd.isna(df["ArrDelay"])])
# Out:
# 154699
